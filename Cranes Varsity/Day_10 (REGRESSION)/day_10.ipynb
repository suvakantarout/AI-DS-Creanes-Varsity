# %% [markdown]
# # REGRESSION®️

# %% [markdown]
# ## Predict Housing Prices Using Single Linear Regression
# ### Dataset Columns (Used in this Question):
# - median_income – Median income in the district (independent variable)
# - median_house_value – Median house value (target/dependent variable)

# %% [markdown]
# ### Your solution should:
# - Load and explore the dataset using pandas.
# - Use median_income as the only feature (independent variable).
# - Train a linear regression model using scikit-learn.
# - Plot the actual data points and the regression line using matplotlib.
# - Calculate and print the following evaluation metrics:
# - Mean Absolute Error (MAE)
# - Root Mean Squared Error (RMSE)
# - R-squared (R²) score

# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('housing.csv')    # Loading the data set(housing.csv)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
X = df[['median_income']]
y = df['median_house_value']

# %%
# Train the model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
mae = mean_absolute_error(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))
r2 = r2_score(y, y_pred)

# %%
print("Mean Squared Error (MSE):", mae)
print("Mean Absolute Error (MAE):", rmse)
print("R² Score:", r2)
# Out:
# Mean Squared Error (MSE): 62625.9337911434
# Mean Absolute Error (MAE): 83733.57452616918
# R² Score: 0.47344749180719903

# %%
plt.figure(figsize=(10,6))
plt.plot(X,y_pred,'o-')
plt.scatter(X, y,color='red')
plt.show()
